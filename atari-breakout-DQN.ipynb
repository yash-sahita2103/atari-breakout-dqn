# %%
import random
import gym
#import math
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dropout
import time
import os
import gc
import psutil
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
#!pip install ale-py
#!pip install gym[atari,accept-rom-license]==0.21.0

# %%
path="./log_model.txt"
EPOCHS = 85 #number of epochs to train for
THRESHOLD = 10 #A threshold where if the Q value exceeds this, we consider the game to be solved
#MONITOR = True #A variable that is used by wrappers in gym

# %%
#Create the DQN class - in this we will code all the necessary attributes and methods to play the game of 
#Breakout for Atari, using DQN

class DQN():
    def __init__(self, env_string,batch_size=64, IM_SIZE = 84, m = 4):
        
        #Initialise memory as a double-ended queue to store experiences (state, action, reward, next_state, done)
        self.memory = deque(maxlen=5000) 
        
        #Attribute to store the environment made by gym - in this case for Breakout-v4
        self.env = gym.make(env_string)

        
        #Do we need this?
        #input_size = self.env.observation_space.shape[0]
        
        #The number of actions that can be taken - in the case of breakout v4 according to documentation
        #the action space is reduced to 4 - NOOP, FIRE, LEFT, RIGHT i.e. action_size = 4
        action_size = self.env.action_space.n
        
        #An attribute for the number of experiences we pass in a batch for training
        self.batch_size = batch_size
        
        self.gamma = 0.9 #Discount factor in update rule
        #self.epsilon = 1.0 #Parameter used for epsilon-greedy action selection
        self.epsilon = 1.0 #Parameter used for epsilon-greedy action selection
        self.epsilon_min = 0.01 #Used when decaying the value of epsilon i.e. less exploration as we learn
        self.epsilon_decay = 0.99925 #Used to control decay of epsilon, less exploration as we learn more
        self.IM_SIZE = IM_SIZE #Square images - dimension size of image fed to CNN part of the network
        self.m = m #Number of images fed together to the network to determine motion - set to 4 consectuive frames
       
        
        alpha=0.001 #learning rate used to control graident descent update step size
        alpha_decay=0.01 #decay factor for learning rate
        
        #We want ot use the Monitor class for the environment to data about observations in a wrapper
        #above the base environment
        #if MONITOR: self.env = gym.wrappers.Monitor(self.env, '../data/'+env_string, force=True)
        
        # Init model - the initial few layers are for the CNN portion of the network, for
        #processing the m=4 images we feed it - 
        self.model = Sequential()
        self.model.add( Conv2D(32, 8, (4,4), activation='elu',padding='valid', input_shape=(IM_SIZE, IM_SIZE, m),kernel_regularizer='l2'))
        self.model.add( Conv2D(64, 4, (2,2), activation='elu',padding='valid',kernel_regularizer='l2'))
        self.model.add( Conv2D(64, 3, (1,1), activation='elu',padding='valid',kernel_regularizer='l2'))
        self.model.add(Flatten())
        self.model.add(Dense(256, activation='elu'))
        self.model.add(Dropout(0.8))
        
        self.model.add(Dense(action_size, activation='linear')) #final layer connects to action_size number of actions
        
        #Loss function - as in slide 8 of week 9 notes - loss is based on squared difference
        #between target and actual Q values baed on weights, for a given state and action
        self.model.compile(loss='mse', optimizer=Adam(lr=alpha, decay=alpha_decay))
        
        #create a clone of the model
        #self.model_target = tf.keras.models.clone_model(self.model) remove for vanilla DQN
        
    def remember(self, state, action, reward, next_state, done):
        #function for appening state, action, reward, next_state, done (as a tuple encompassing that experience) 
        #to memory (which as above is a double-ended queue of experiences)
        self.memory.append((state, action, reward, next_state, done))

    def choose_action(self, state, epsilon):
        #This is essentially epsilon-greedy action selection
        
        #randomly choose a number in range 0-1, so with probability epsilon i.e. if it the
        #random number is less than epsilon - sample a random action from the action_space
        #This is how we incorporate exploration
        if np.random.random() <= epsilon:
            return self.env.action_space.sample() #randomly chosen action
        else:
            #With probability 1-epsilon, we stick to the action that maximises Q value - model returns prediction of actions
            return np.argmax(self.model.predict(state,verbose=0))
        
    def preprocess_state(self, img):
        # Choose the important area of the image - ignore score at top
        #values for cropping here were chosen based on outputs of cell above
        img_temp = img[31:195] 
        #This is a preprocessing function for cropping and resizing images and convert them to grayscale
        img_temp = tf.image.rgb_to_grayscale(img_temp) #convert to grayscale 
        #resize the image to be square (IM_SIZE X IM_SIZE pixels), using tensorflow's nearest neighbour resize method
        #for interpolation
        img_temp = tf.image.resize(img_temp, [self.IM_SIZE, self.IM_SIZE],
                                   method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
        #convert image to float32
        img_temp = tf.cast(img_temp, tf.float32)
        return img_temp[:,:,0]
    
    def combine_images(self, img1, img2):
        #function for combining images together
        if len(img1.shape) == 3 and img1.shape[0] == self.m:
            im = np.append(img1[1:,:, :],np.expand_dims(img2,0), axis=2)
            return tf.expand_dims(im, 0)
        else:
            im = np.stack([img1]*self.m, axis = 2)
            return tf.expand_dims(im, 0)
        
    def replay(self, batch_size):
        x_batch, y_batch = [], []
        #Chunk memory into minibatches of experience to train on - create targets and Q values of the current state (i.e. x)
        minibatch = random.sample(self.memory, min(len(self.memory), batch_size))
        for state, action, reward, next_state, done in minibatch:
            y_target = self.model.predict(state,verbose=0)
            #print("y_target for model_target predict",y_target)
            #this is the target for DQN
            #the reward if reaching the terminal state
            #otherwise the discounted Q value for the next state
            #print("y_target[0][action] before ",y_target[0][action])
            y_target[0][action] = reward if done else reward + self.gamma * np.max(self.model.predict(next_state,verbose=0)[0])
            #print("y_target[0][action] after ",y_target[0][action])
            #print("y_target for model predict",self.model.predict(next_state,verbose=0))
            x_batch.append(state[0])
            y_batch.append(y_target[0])
        
        #fit the model based on targets and values
        self.model.fit(np.array(x_batch), np.array(y_batch), batch_size=len(x_batch), verbose=0)
        
    def train(self):
        #scores are a double-ended queue of length 100
        scores = deque(maxlen=100)
        #array for avergae scores - want to show average score per episode is increasing over epochs
        avg_scores = []
        steps_per_episode_list=[]
        episilon_list=[]
        
        print('Epsilon: '+str(self.epsilon))
        for e in range(EPOCHS):
            print("\n Episode number : "+str(e))
            print("-----------------------------------------------------------------------------")
            state = self.env.reset()
            #preprocess the state to get cropped, grayscale images
            state = self.preprocess_state(state)
            #combine the image
            state = self.combine_images(state, state)
            done = False #initially we do not start at the terminal state
            i = 0 #counter for recording score
            start = time.time()
            steps_per_episode=0
            while not done:
                action = self.choose_action(state,self.epsilon) #choose an action based on epsilon-greedy policy
                next_state, reward, done, _ = self.env.step(action) #consider next state, reward, done, based on that action
                next_state = self.preprocess_state(next_state) 
                next_state = self.combine_images(next_state, state)
                self.remember(state, action, reward, next_state, done) #append experience to memory
                state = next_state #transition to next_state
                self.epsilon = max(self.epsilon_min, self.epsilon_decay*self.epsilon) # decrease epsilon
                i += reward
                steps_per_episode+=1

            scores.append(i) #update score 
            mean_score = np.mean(scores)
            avg_scores.append(mean_score) #update average score
            steps_per_episode_list.append(steps_per_episode)
            episilon_list.append(self.epsilon)
            
            if mean_score >= THRESHOLD:
                print('Solved after {} trials ✔'.format(e))
                return avg_scores
            
            #if e>20:
            self.replay(self.batch_size)
            
            end = time.time()
            with open(path,'w') as f:
                f.write(str({"avg_scores":avg_scores,"steps_per_episode_list":steps_per_episode_list,"episilon_list":episilon_list}))
                
            print('[Episode '+str(e)+'] - Average Score: '+str(mean_score))
            print('[Episode '+str(e)+'] - Epsilon: '+str(self.epsilon))
            print('[Episode '+str(e)+'] - Total Steps: '+str(steps_per_episode))
            print('RAM memory % used:', psutil.virtual_memory()[2])
            print('RAM Used (GB):', psutil.virtual_memory()[3]/1000000000)
            gc.collect()
            print("Time Taken : ",str(end-start))
        
        return avg_scores,steps_per_episode_list,episilon_list

# %%
env_string = 'BreakoutDeterministic-v4'
agent = DQN(env_string)
# Out:
# C:\Users\yashs\anaconda3\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
import matplotlib.pyplot as plt 
plt.imshow(agent.env.render(mode='rgb_array'))

# %%
print(agent.env.action_space.n)
print(agent.env.get_action_meanings())
# Out:
# 4
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']

# %%
print(agent.env.observation_space.shape)
# Out:
# (210, 160, 3)

# %%
agent.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 256)               803072
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 882,084
# Trainable params: 882,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores,steps_per_episode_list,episilon_list = agent.train()
# Out:
# Epsilon: 1.0
#
#  Episode number : 0
# -----------------------------------------------------------------------------
# [Episode 0] - Average Score: 2.0
# [Episode 0] - Epsilon: 0.8741991560384481
# [Episode 0] - Total Steps: 192
# RAM memory % used: 54.7
# RAM Used (GB): 9.22279936
# Time Taken :  8.703848838806152
#
#  Episode number : 1
# -----------------------------------------------------------------------------
# [Episode 1] - Average Score: 1.5
# [Episode 1] - Epsilon: 0.7722936333362159
# [Episode 1] - Total Steps: 177
# RAM memory % used: 54.9
# RAM Used (GB): 9.254068224
# Time Taken :  6.961931228637695
#
#  Episode number : 2
# -----------------------------------------------------------------------------
# [Episode 2] - Average Score: 1.3333333333333333
# [Episode 2] - Epsilon: 0.6822672522294481
# [Episode 2] - Total Steps: 177
# RAM memory % used: 55.2
# RAM Used (GB): 9.310482432
# Time Taken :  8.015123128890991
#
#  Episode number : 3
# -----------------------------------------------------------------------------
# [Episode 3] - Average Score: 1.0
# [Episode 3] - Epsilon: 0.6220304779282642
# [Episode 3] - Total Steps: 132
# RAM memory % used: 55.5
# RAM Used (GB): 9.361575936
# Time Taken :  7.346018552780151
#
#  Episode number : 4
# -----------------------------------------------------------------------------
# [Episode 4] - Average Score: 1.0
# [Episode 4] - Epsilon: 0.5502904316532444
# [Episode 4] - Total Steps: 175
# RAM memory % used: 55.9
# RAM Used (GB): 9.432141824
# Time Taken :  9.19853687286377
#
#  Episode number : 5
# -----------------------------------------------------------------------------
# [Episode 5] - Average Score: 1.1666666666666667
# [Episode 5] - Epsilon: 0.4730462915604007
# [Episode 5] - Total Steps: 216
# RAM memory % used: 57.1
# RAM Used (GB): 9.633005568
# Time Taken :  10.718619585037231
#
#  Episode number : 6
# -----------------------------------------------------------------------------
# [Episode 6] - Average Score: 1.2857142857142858
# [Episode 6] - Epsilon: 0.40522362751188545
# [Episode 6] - Total Steps: 221
# RAM memory % used: 57.1
# RAM Used (GB): 9.629478912
# Time Taken :  11.740478992462158
#
#  Episode number : 7
# -----------------------------------------------------------------------------
# [Episode 7] - Average Score: 1.125
# [Episode 7] - Epsilon: 0.35773605968999356
# [Episode 7] - Total Steps: 178
# RAM memory % used: 57.6
# RAM Used (GB): 9.720971264
# Time Taken :  10.426418781280518
#
#  Episode number : 8
# -----------------------------------------------------------------------------
# [Episode 8] - Average Score: 1.2222222222222223
# [Episode 8] - Epsilon: 0.3114213811474643
# [Episode 8] - Total Steps: 198
# RAM memory % used: 58.2
# RAM Used (GB): 9.809911808
# Time Taken :  11.77571702003479
#
#  Episode number : 9
# -----------------------------------------------------------------------------
# [Episode 9] - Average Score: 1.9
# [Episode 9] - Epsilon: 0.2506533560332706
# [Episode 9] - Total Steps: 310
# RAM memory % used: 58.9
# RAM Used (GB): 9.931431936
# Time Taken :  15.911627769470215
#
#  Episode number : 10
# -----------------------------------------------------------------------------
# [Episode 10] - Average Score: 1.7272727272727273
# [Episode 10] - Epsilon: 0.22996814144449665
# [Episode 10] - Total Steps: 123
# RAM memory % used: 59.7
# RAM Used (GB): 10.072051712
# Time Taken :  9.656798839569092
#
#  Episode number : 11
# -----------------------------------------------------------------------------
# [Episode 11] - Average Score: 2.1666666666666665
# [Episode 11] - Epsilon: 0.18809937922069558
# [Episode 11] - Total Steps: 287
# RAM memory % used: 60.3
# RAM Used (GB): 10.178789376
# Time Taken :  16.05901026725769
#
#  Episode number : 12
# -----------------------------------------------------------------------------
# [Episode 12] - Average Score: 2.0
# [Episode 12] - Epsilon: 0.16887059109311348
# [Episode 12] - Total Steps: 154
# RAM memory % used: 61.1
# RAM Used (GB): 10.306637824
# Time Taken :  11.574807405471802
#
#  Episode number : 13
# -----------------------------------------------------------------------------
# [Episode 13] - Average Score: 2.0714285714285716
# [Episode 13] - Epsilon: 0.12365848497485894
# [Episode 13] - Total Steps: 445
# RAM memory % used: 61.7
# RAM Used (GB): 10.39966208
# Time Taken :  23.74954915046692
#
#  Episode number : 14
# -----------------------------------------------------------------------------
# [Episode 14] - Average Score: 2.6666666666666665
# [Episode 14] - Epsilon: 0.08478269858485502
# [Episode 14] - Total Steps: 539
# RAM memory % used: 63.3
# RAM Used (GB): 10.681339904
# Time Taken :  28.253647565841675
#
#  Episode number : 15
# -----------------------------------------------------------------------------
# [Episode 15] - Average Score: 3.1875
# [Episode 15] - Epsilon: 0.06411598412828451
# [Episode 15] - Total Steps: 399
# RAM memory % used: 66.2
# RAM Used (GB): 11.173875712
# Time Taken :  24.558067083358765
#
#  Episode number : 16
# -----------------------------------------------------------------------------
# [Episode 16] - Average Score: 3.6470588235294117
# [Episode 16] - Epsilon: 0.04744581371728179
# [Episode 16] - Total Steps: 430
# RAM memory % used: 68.6
# RAM Used (GB): 11.5777536
# Time Taken :  24.84290599822998
#
#  Episode number : 17
# -----------------------------------------------------------------------------
# [Episode 17] - Average Score: 4.055555555555555
# [Episode 17] - Epsilon: 0.031213219831424645
# [Episode 17] - Total Steps: 598
# RAM memory % used: 69.3
# RAM Used (GB): 11.692621824
# Time Taken :  32.356481075286865
#
#  Episode number : 18
# -----------------------------------------------------------------------------
# [Episode 18] - Average Score: 4.421052631578948
# [Episode 18] - Epsilon: 0.01
# [Episode 18] - Total Steps: 1960
# RAM memory % used: 72.4
# RAM Used (GB): 12.215042048
# Time Taken :  96.52429270744324
#
#  Episode number : 19
# -----------------------------------------------------------------------------
# [Episode 19] - Average Score: 4.75
# [Episode 19] - Epsilon: 0.01
# [Episode 19] - Total Steps: 1928
# RAM memory % used: 75.9
# RAM Used (GB): 12.802678784
# Time Taken :  96.61618971824646
#
#  Episode number : 20
# -----------------------------------------------------------------------------
# [Episode 20] - Average Score: 5.0476190476190474
# [Episode 20] - Epsilon: 0.01
# [Episode 20] - Total Steps: 3915
# RAM memory % used: 82.8
# RAM Used (GB): 13.964242944
# Time Taken :  193.1988890171051
#
#  Episode number : 21
# -----------------------------------------------------------------------------
# [Episode 21] - Average Score: 5.318181818181818
# [Episode 21] - Epsilon: 0.01
# [Episode 21] - Total Steps: 3052
# RAM memory % used: 88.6
# RAM Used (GB): 14.939009024
# Time Taken :  150.17099618911743
#
#  Episode number : 22
# -----------------------------------------------------------------------------
# [Episode 22] - Average Score: 5.565217391304348
# [Episode 22] - Epsilon: 0.01
# [Episode 22] - Total Steps: 2964
# RAM memory % used: 91.6
# RAM Used (GB): 15.445540864
# Time Taken :  143.37731885910034
#
#  Episode number : 23
# -----------------------------------------------------------------------------
# [Episode 23] - Average Score: 5.791666666666667
# [Episode 23] - Epsilon: 0.01
# [Episode 23] - Total Steps: 2159
# RAM memory % used: 95.5
# RAM Used (GB): 16.114126848
# Time Taken :  108.45677924156189
#
#  Episode number : 24
# -----------------------------------------------------------------------------
# [Episode 24] - Average Score: 6.0
# [Episode 24] - Epsilon: 0.01
# [Episode 24] - Total Steps: 1882
# RAM memory % used: 87.8
# RAM Used (GB): 14.80566784
# Time Taken :  94.62485003471375
#
#  Episode number : 25
# -----------------------------------------------------------------------------
# [Episode 25] - Average Score: 6.1923076923076925
# [Episode 25] - Epsilon: 0.01
# [Episode 25] - Total Steps: 1407
# RAM memory % used: 90.5
# RAM Used (GB): 15.258107904
# Time Taken :  72.74179124832153
#
#  Episode number : 26
# -----------------------------------------------------------------------------
# [Episode 26] - Average Score: 6.37037037037037
# [Episode 26] - Epsilon: 0.01
# [Episode 26] - Total Steps: 3204
# RAM memory % used: 95.3
# RAM Used (GB): 16.067166208
# Time Taken :  156.5156228542328
#
#  Episode number : 27
# -----------------------------------------------------------------------------
# [Episode 27] - Average Score: 6.535714285714286
# [Episode 27] - Epsilon: 0.01
# [Episode 27] - Total Steps: 2114
# RAM memory % used: 94.6
# RAM Used (GB): 15.963947008
# Time Taken :  107.3196632862091
#
#  Episode number : 28
# -----------------------------------------------------------------------------
# [Episode 28] - Average Score: 6.689655172413793
# [Episode 28] - Epsilon: 0.01
# [Episode 28] - Total Steps: 1324
# RAM memory % used: 96.1
# RAM Used (GB): 16.216195072
# Time Taken :  67.8249282836914
#
#  Episode number : 29
# -----------------------------------------------------------------------------
# [Episode 29] - Average Score: 6.833333333333333
# [Episode 29] - Epsilon: 0.01
# [Episode 29] - Total Steps: 897
# RAM memory % used: 97.2
# RAM Used (GB): 16.400191488
# Time Taken :  47.59629940986633
#
#  Episode number : 30
# -----------------------------------------------------------------------------
# [Episode 30] - Average Score: 6.967741935483871
# [Episode 30] - Epsilon: 0.01
# [Episode 30] - Total Steps: 1741
# RAM memory % used: 98.0
# RAM Used (GB): 16.532967424
# Time Taken :  87.91971182823181
#
#  Episode number : 31
# -----------------------------------------------------------------------------
# [Episode 31] - Average Score: 7.09375
# [Episode 31] - Epsilon: 0.01
# [Episode 31] - Total Steps: 2309
# RAM memory % used: 93.8
# RAM Used (GB): 15.826587648
# Time Taken :  115.14783787727356
#
#  Episode number : 32
# -----------------------------------------------------------------------------
# [Episode 32] - Average Score: 7.212121212121212
# [Episode 32] - Epsilon: 0.01
# [Episode 32] - Total Steps: 1933
# RAM memory % used: 97.3
# RAM Used (GB): 16.406372352
# Time Taken :  97.25026082992554
#
#  Episode number : 33
# -----------------------------------------------------------------------------
# [Episode 33] - Average Score: 7.323529411764706
# [Episode 33] - Epsilon: 0.01
# [Episode 33] - Total Steps: 1570
# RAM memory % used: 98.2
# RAM Used (GB): 16.565805056
# Time Taken :  79.81653451919556
#
#  Episode number : 34
# -----------------------------------------------------------------------------
# [Episode 34] - Average Score: 7.428571428571429
# [Episode 34] - Epsilon: 0.01
# [Episode 34] - Total Steps: 1468
# RAM memory % used: 91.0
# RAM Used (GB): 15.34797824
# Time Taken :  75.19956851005554
#
#  Episode number : 35
# -----------------------------------------------------------------------------
# [Episode 35] - Average Score: 7.527777777777778
# [Episode 35] - Epsilon: 0.01
# [Episode 35] - Total Steps: 1375
# RAM memory % used: 93.7
# RAM Used (GB): 15.801667584
# Time Taken :  71.02401685714722
#
#  Episode number : 36
# -----------------------------------------------------------------------------
# [Episode 36] - Average Score: 7.621621621621622
# [Episode 36] - Epsilon: 0.01
# [Episode 36] - Total Steps: 1980
# RAM memory % used: 97.5
# RAM Used (GB): 16.452493312
# Time Taken :  101.420166015625
#
#  Episode number : 37
# -----------------------------------------------------------------------------
# [Episode 37] - Average Score: 7.7105263157894735
# [Episode 37] - Epsilon: 0.01
# [Episode 37] - Total Steps: 1247
# RAM memory % used: 98.7
# RAM Used (GB): 16.653770752
# Time Taken :  65.81331324577332
#
#  Episode number : 38
# -----------------------------------------------------------------------------
# [Episode 38] - Average Score: 7.794871794871795
# [Episode 38] - Epsilon: 0.01
# [Episode 38] - Total Steps: 1087
# RAM memory % used: 96.0
# RAM Used (GB): 16.185368576
# Time Taken :  59.479559898376465
#
#  Episode number : 39
# -----------------------------------------------------------------------------
# [Episode 39] - Average Score: 7.875
# [Episode 39] - Epsilon: 0.01
# [Episode 39] - Total Steps: 1231
# RAM memory % used: 97.5
# RAM Used (GB): 16.452100096
# Time Taken :  67.25973629951477
#
#  Episode number : 40
# -----------------------------------------------------------------------------
# [Episode 40] - Average Score: 7.951219512195122
# [Episode 40] - Epsilon: 0.01
# [Episode 40] - Total Steps: 1727
# RAM memory % used: 98.0
# RAM Used (GB): 16.523771904
# Time Taken :  90.44368934631348
#
#  Episode number : 41
# -----------------------------------------------------------------------------
# [Episode 41] - Average Score: 8.023809523809524
# [Episode 41] - Epsilon: 0.01
# [Episode 41] - Total Steps: 3295
# RAM memory % used: 95.8
# RAM Used (GB): 16.166842368
# Time Taken :  168.0701503753662
#
#  Episode number : 42
# -----------------------------------------------------------------------------
# [Episode 42] - Average Score: 8.093023255813954
# [Episode 42] - Epsilon: 0.01
# [Episode 42] - Total Steps: 1343
# RAM memory % used: 98.2
# RAM Used (GB): 16.56098816
# Time Taken :  70.04618716239929
#
#  Episode number : 43
# -----------------------------------------------------------------------------
# [Episode 43] - Average Score: 8.159090909090908
# [Episode 43] - Epsilon: 0.01
# [Episode 43] - Total Steps: 937
# RAM memory % used: 97.1
# RAM Used (GB): 16.377905152
# Time Taken :  51.182145833969116
#
#  Episode number : 44
# -----------------------------------------------------------------------------
# [Episode 44] - Average Score: 8.222222222222221
# [Episode 44] - Epsilon: 0.01
# [Episode 44] - Total Steps: 3840
# RAM memory % used: 88.3
# RAM Used (GB): 14.885453824
# Time Taken :  190.70647168159485
#
#  Episode number : 45
# -----------------------------------------------------------------------------
# [Episode 45] - Average Score: 8.282608695652174
# [Episode 45] - Epsilon: 0.01
# [Episode 45] - Total Steps: 2676
# RAM memory % used: 94.2
# RAM Used (GB): 15.888678912
# Time Taken :  131.8845386505127
#
#  Episode number : 46
# -----------------------------------------------------------------------------
# [Episode 46] - Average Score: 8.340425531914894
# [Episode 46] - Epsilon: 0.01
# [Episode 46] - Total Steps: 2394
# RAM memory % used: 96.8
# RAM Used (GB): 16.32047104
# Time Taken :  122.71549892425537
#
#  Episode number : 47
# -----------------------------------------------------------------------------
# [Episode 47] - Average Score: 8.395833333333334
# [Episode 47] - Epsilon: 0.01
# [Episode 47] - Total Steps: 944
# RAM memory % used: 94.3
# RAM Used (GB): 15.905820672
# Time Taken :  51.508564949035645
#
#  Episode number : 48
# -----------------------------------------------------------------------------
# [Episode 48] - Average Score: 8.448979591836734
# [Episode 48] - Epsilon: 0.01
# [Episode 48] - Total Steps: 1505
# RAM memory % used: 98.2
# RAM Used (GB): 16.562069504
# Time Taken :  81.59888172149658
#
#  Episode number : 49
# -----------------------------------------------------------------------------
# [Episode 49] - Average Score: 8.5
# [Episode 49] - Epsilon: 0.01
# [Episode 49] - Total Steps: 1659
# RAM memory % used: 98.2
# RAM Used (GB): 16.567996416
# Time Taken :  89.97055530548096
#
#  Episode number : 50
# -----------------------------------------------------------------------------
# [Episode 50] - Average Score: 8.470588235294118
# [Episode 50] - Epsilon: 0.01
# [Episode 50] - Total Steps: 1638
# RAM memory % used: 93.9
# RAM Used (GB): 15.834075136
# Time Taken :  87.99722075462341
#
#  Episode number : 51
# -----------------------------------------------------------------------------
# [Episode 51] - Average Score: 8.51923076923077
# [Episode 51] - Epsilon: 0.01
# [Episode 51] - Total Steps: 2799
# RAM memory % used: 96.2
# RAM Used (GB): 16.232448
# Time Taken :  146.47290420532227
#
#  Episode number : 52
# -----------------------------------------------------------------------------
# [Episode 52] - Average Score: 8.566037735849056
# [Episode 52] - Epsilon: 0.01
# [Episode 52] - Total Steps: 2743
# RAM memory % used: 95.0
# RAM Used (GB): 16.017149952
# Time Taken :  145.54104566574097
#
#  Episode number : 53
# -----------------------------------------------------------------------------
# [Episode 53] - Average Score: 8.61111111111111
# [Episode 53] - Epsilon: 0.01
# [Episode 53] - Total Steps: 2687
# RAM memory % used: 98.3
# RAM Used (GB): 16.584192
# Time Taken :  142.061598777771
#
#  Episode number : 54
# -----------------------------------------------------------------------------
# [Episode 54] - Average Score: 8.654545454545454
# [Episode 54] - Epsilon: 0.01
# [Episode 54] - Total Steps: 1765
# RAM memory % used: 98.0
# RAM Used (GB): 16.529125376
# Time Taken :  93.89064598083496
#
#  Episode number : 55
# -----------------------------------------------------------------------------
# [Episode 55] - Average Score: 8.696428571428571
# [Episode 55] - Epsilon: 0.01
# [Episode 55] - Total Steps: 3368
# RAM memory % used: 97.9
# RAM Used (GB): 16.513376256
# Time Taken :  209.46481776237488
#
#  Episode number : 56
# -----------------------------------------------------------------------------
# [Episode 56] - Average Score: 8.736842105263158
# [Episode 56] - Epsilon: 0.01
# [Episode 56] - Total Steps: 1581
# RAM memory % used: 98.3
# RAM Used (GB): 16.57204736
# Time Taken :  81.87573957443237
#
#  Episode number : 57
# -----------------------------------------------------------------------------
# [Episode 57] - Average Score: 8.775862068965518
# [Episode 57] - Epsilon: 0.01
# [Episode 57] - Total Steps: 1358
# RAM memory % used: 95.3
# RAM Used (GB): 16.0728064
# Time Taken :  71.1036376953125
#
#  Episode number : 58
# -----------------------------------------------------------------------------
# [Episode 58] - Average Score: 8.813559322033898
# [Episode 58] - Epsilon: 0.01
# [Episode 58] - Total Steps: 2833
# RAM memory % used: 95.1
# RAM Used (GB): 16.03975168
# Time Taken :  146.37780261039734
#
#  Episode number : 59
# -----------------------------------------------------------------------------
# [Episode 59] - Average Score: 8.85
# [Episode 59] - Epsilon: 0.01
# [Episode 59] - Total Steps: 3170
# RAM memory % used: 90.8
# RAM Used (GB): 15.313461248
# Time Taken :  164.76852822303772
#
#  Episode number : 60
# -----------------------------------------------------------------------------
# [Episode 60] - Average Score: 8.885245901639344
# [Episode 60] - Epsilon: 0.01
# [Episode 60] - Total Steps: 2665
# RAM memory % used: 96.3
# RAM Used (GB): 16.246718464
# Time Taken :  138.60912775993347
#
#  Episode number : 61
# -----------------------------------------------------------------------------
# [Episode 61] - Average Score: 8.919354838709678
# [Episode 61] - Epsilon: 0.01
# [Episode 61] - Total Steps: 2741
# RAM memory % used: 91.9
# RAM Used (GB): 15.502979072
# Time Taken :  148.02024364471436
#
#  Episode number : 62
# -----------------------------------------------------------------------------
# [Episode 62] - Average Score: 8.952380952380953
# [Episode 62] - Epsilon: 0.01
# [Episode 62] - Total Steps: 1878
# RAM memory % used: 96.8
# RAM Used (GB): 16.327409664
# Time Taken :  101.53498029708862
#
#  Episode number : 63
# -----------------------------------------------------------------------------
# [Episode 63] - Average Score: 8.984375
# [Episode 63] - Epsilon: 0.01
# [Episode 63] - Total Steps: 4069
# RAM memory % used: 88.0
# RAM Used (GB): 14.850875392
# Time Taken :  230.18973565101624
#
#  Episode number : 64
# -----------------------------------------------------------------------------
# [Episode 64] - Average Score: 9.015384615384615
# [Episode 64] - Epsilon: 0.01
# [Episode 64] - Total Steps: 2011
# RAM memory % used: 92.4
# RAM Used (GB): 15.578734592
# Time Taken :  107.39818120002747
#
#  Episode number : 65
# -----------------------------------------------------------------------------
# [Episode 65] - Average Score: 9.045454545454545
# [Episode 65] - Epsilon: 0.01
# [Episode 65] - Total Steps: 1269
# RAM memory % used: 93.8
# RAM Used (GB): 15.823396864
# Time Taken :  70.2329843044281
#
#  Episode number : 66
# -----------------------------------------------------------------------------
# [Episode 66] - Average Score: 9.074626865671641
# [Episode 66] - Epsilon: 0.01
# [Episode 66] - Total Steps: 2390
# RAM memory % used: 91.4
# RAM Used (GB): 15.416905728
# Time Taken :  128.27281975746155
#
#  Episode number : 67
# -----------------------------------------------------------------------------
# [Episode 67] - Average Score: 9.102941176470589
# [Episode 67] - Epsilon: 0.01
# [Episode 67] - Total Steps: 3375
# RAM memory % used: 98.2
# RAM Used (GB): 16.55990272
# Time Taken :  179.13188314437866
#
#  Episode number : 68
# -----------------------------------------------------------------------------
# [Episode 68] - Average Score: 9.130434782608695
# [Episode 68] - Epsilon: 0.01
# [Episode 68] - Total Steps: 1355
# RAM memory % used: 93.8
# RAM Used (GB): 15.824457728
# Time Taken :  76.65435576438904
#
#  Episode number : 69
# -----------------------------------------------------------------------------
# [Episode 69] - Average Score: 9.157142857142857
# [Episode 69] - Epsilon: 0.01
# [Episode 69] - Total Steps: 1608
# RAM memory % used: 98.1
# RAM Used (GB): 16.55066624
# Time Taken :  89.17421913146973
#
#  Episode number : 70
# -----------------------------------------------------------------------------
# [Episode 70] - Average Score: 9.183098591549296
# [Episode 70] - Epsilon: 0.01
# [Episode 70] - Total Steps: 1894
# RAM memory % used: 98.2
# RAM Used (GB): 16.56100864
# Time Taken :  124.13110303878784
#
#  Episode number : 71
# -----------------------------------------------------------------------------
# [Episode 71] - Average Score: 9.208333333333334
# [Episode 71] - Epsilon: 0.01
# [Episode 71] - Total Steps: 3506
# RAM memory % used: 90.5
# RAM Used (GB): 15.265071104
# Time Taken :  246.09251594543457
#
#  Episode number : 72
# -----------------------------------------------------------------------------
# [Episode 72] - Average Score: 9.232876712328768
# [Episode 72] - Epsilon: 0.01
# [Episode 72] - Total Steps: 2642
# RAM memory % used: 82.2
# RAM Used (GB): 13.87073536
# Time Taken :  175.61479258537292
#
#  Episode number : 73
# -----------------------------------------------------------------------------
# [Episode 73] - Average Score: 9.256756756756756
# [Episode 73] - Epsilon: 0.01
# [Episode 73] - Total Steps: 1446
# RAM memory % used: 86.9
# RAM Used (GB): 14.664220672
# Time Taken :  82.47162652015686
#
#  Episode number : 74
# -----------------------------------------------------------------------------
# [Episode 74] - Average Score: 9.28
# [Episode 74] - Epsilon: 0.01
# [Episode 74] - Total Steps: 2242
# RAM memory % used: 93.1
# RAM Used (GB): 15.709741056
# Time Taken :  124.46525692939758
#
#  Episode number : 75
# -----------------------------------------------------------------------------
# [Episode 75] - Average Score: 9.302631578947368
# [Episode 75] - Epsilon: 0.01
# [Episode 75] - Total Steps: 2300
# RAM memory % used: 94.0
# RAM Used (GB): 15.849066496
# Time Taken :  127.61625337600708
#
#  Episode number : 76
# -----------------------------------------------------------------------------
# [Episode 76] - Average Score: 9.324675324675324
# [Episode 76] - Epsilon: 0.01
# [Episode 76] - Total Steps: 2418
# RAM memory % used: 98.0
# RAM Used (GB): 16.52686848
# Time Taken :  132.3607439994812
#
#  Episode number : 77
# -----------------------------------------------------------------------------
# [Episode 77] - Average Score: 9.346153846153847
# [Episode 77] - Epsilon: 0.01
# [Episode 77] - Total Steps: 1429
# RAM memory % used: 98.2
# RAM Used (GB): 16.56459264
# Time Taken :  81.7428228855133
#
#  Episode number : 78
# -----------------------------------------------------------------------------
# [Episode 78] - Average Score: 9.367088607594937
# [Episode 78] - Epsilon: 0.01
# [Episode 78] - Total Steps: 1532
# RAM memory % used: 98.1
# RAM Used (GB): 16.545292288
# Time Taken :  86.34485411643982
#
#  Episode number : 79
# -----------------------------------------------------------------------------
# [Episode 79] - Average Score: 9.3875
# [Episode 79] - Epsilon: 0.01
# [Episode 79] - Total Steps: 1162
# RAM memory % used: 96.6
# RAM Used (GB): 16.299737088
# Time Taken :  71.45147228240967
#
#  Episode number : 80
# -----------------------------------------------------------------------------
# [Episode 80] - Average Score: 9.407407407407407
# [Episode 80] - Epsilon: 0.01
# [Episode 80] - Total Steps: 3025
# RAM memory % used: 98.4
# RAM Used (GB): 16.596975616
# Time Taken :  203.41002583503723
#
#  Episode number : 81
# -----------------------------------------------------------------------------
# [Episode 81] - Average Score: 9.426829268292684
# [Episode 81] - Epsilon: 0.01
# [Episode 81] - Total Steps: 2167
# RAM memory % used: 98.4
# RAM Used (GB): 16.592121856
# Time Taken :  140.018235206604
#
#  Episode number : 82
# -----------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
plt.plot(scores)
plt.title("Score per Episode")
plt.xlabel('Episode')
plt.ylabel('Score') 
plt.show()

# %%
plt.plot(steps_per_episode_list)
plt.title("Steps per Episode")
plt.xlabel('Episode')
plt.ylabel('Steps') 
plt.show()

# %%
plt.plot(episilon_list)
plt.title("Epsilon Decay")
plt.xlabel('Episode')
plt.ylabel('Epsilon') 
plt.show()
